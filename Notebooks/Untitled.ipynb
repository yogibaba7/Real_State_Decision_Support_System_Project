# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('BPL_outliers_treated.csv')

# %%
df.shape
# Out:
# (1572, 20)

# %%
df.isnull().sum()
# Out:
# society                     4
# colony                      0
# property_type               0
# price                       0
# price_per_sqft              0
# Total Floors               33
# Facing                    698
# bedrooms                    0
# bathrooms                   0
# balconies                   0
# mainarea                    0
# study room                  0
# servant room                0
# store room                  0
# pooja room                  0
# others                      0
# view floor plan             0
# furnishing_type             0
# luxury_score                0
# Overlooking_Categories      0
# dtype: int64
