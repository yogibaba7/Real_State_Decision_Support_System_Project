# %%
import pandas as pd 
import numpy as np

# %%
houses = pd.read_csv('bpl_house_cleaned_l1.csv')
flats = pd.read_csv('bpl_flats_cleaned_l1.csv')

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pname            798 non-null    object
#  1   society          797 non-null    object
#  2   price_outer      798 non-null    float64
#  3   price_per_sqft   798 non-null    int64
#  4   possesion        798 non-null    object
#  5   description      798 non-null    object
#  6   Area             798 non-null    object
#  7   Total Floors     764 non-null    float64
#  8   Facing           485 non-null    object
#  9   Property Age     715 non-null    object
#  10  furnishing       302 non-null    object
#  11  features         447 non-null    object
#  12  Overlooking      378 non-null    object
#  13  bedrooms         798 non-null    int64
#  14  bathrooms        798 non-null    int64
#  15  balconies        798 non-null    int64
#  16  additional_room  798 non-null    object
# ...

# %%
flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pname            782 non-null    object
#  1   society          779 non-null    object
#  2   price_outer      782 non-null    float64
#  3   price_per_sqft   782 non-null    int64
#  4   possesion        782 non-null    object
#  5   description      782 non-null    object
#  6   Area             782 non-null    object
#  7   Floor Number     782 non-null    object
#  8   Facing           391 non-null    object
#  9   Property Age     728 non-null    object
#  10  furnishing       371 non-null    object
#  11  features         568 non-null    object
#  12  Overlooking      414 non-null    object
#  13  bedrooms         782 non-null    int64
#  14  bathrooms        782 non-null    int64
#  15  balconies        782 non-null    int64
#  16  additional_room  782 non-null    object
# ...

# %%
flats.rename(columns={'Floor Number':'Total Floors'},inplace=True)

# %%
flats['Total Floors'] = flats['Floor_On']

# %%
flats.head(2)
# Out:
#                             pname               society  price_outer  \
# 0  3 BHK Flat in Shahpura, Bhopal         green heights         75.0
# 1  3 BHK Flat in MP Nagar, Bhopal  keelandev apartments        185.0
#
#    price_per_sqft      possesion  \
# 0            6000  Ready To Move
# 1           10481  Ready To Move
#
#                                          description  \
# 0  Situated in shahpura, bhopal, green heights is...
# 1  For sale 3.5 bhk flat kilandev tower shivaji n...
#
#                                                 Area  Total Floors  \
# 0        Carpet area: 1250\n(116.13 sq.m.)  \nsq.ft.             1
# 1  Super Built up area 1765\n(163.97 sq.m.)  \nsq...             5
#
#        Facing      Property Age  \
# 0        East  5 to 10 Year Old
# 1  North-West   1 to 5 Year Old
#
#                                           furnishing  \
# 0  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '3 Ge...
# 1  ['2 Wardrobe', '3 Fan', '1 Exhaust Fan', '2 Ge...
#
# ...

# %%
flats.drop(columns=['Floor_On','Total_Floors'],inplace=True)

# %%
flats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pname            782 non-null    object
#  1   society          779 non-null    object
#  2   price_outer      782 non-null    float64
#  3   price_per_sqft   782 non-null    int64
#  4   possesion        782 non-null    object
#  5   description      782 non-null    object
#  6   Area             782 non-null    object
#  7   Total Floors     782 non-null    int64
#  8   Facing           391 non-null    object
#  9   Property Age     728 non-null    object
#  10  furnishing       371 non-null    object
#  11  features         568 non-null    object
#  12  Overlooking      414 non-null    object
#  13  bedrooms         782 non-null    int64
#  14  bathrooms        782 non-null    int64
#  15  balconies        782 non-null    int64
#  16  additional_room  782 non-null    object
# ...

# %%
flats.insert(2,'property_type','Flat')

# %%
houses.insert(2,'property_type','House')

# %%
flats.head(2)
# Out:
#                             pname               society property_type  \
# 0  3 BHK Flat in Shahpura, Bhopal         green heights          Flat
# 1  3 BHK Flat in MP Nagar, Bhopal  keelandev apartments          Flat
#
#    price_outer  price_per_sqft      possesion  \
# 0         75.0            6000  Ready To Move
# 1        185.0           10481  Ready To Move
#
#                                          description  \
# 0  Situated in shahpura, bhopal, green heights is...
# 1  For sale 3.5 bhk flat kilandev tower shivaji n...
#
#                                                 Area  Total Floors  \
# 0        Carpet area: 1250\n(116.13 sq.m.)  \nsq.ft.             1
# 1  Super Built up area 1765\n(163.97 sq.m.)  \nsq...             5
#
#        Facing      Property Age  \
# 0        East  5 to 10 Year Old
# 1  North-West   1 to 5 Year Old
#
#                                           furnishing  \
# 0  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '3 Ge...
# ...

# %%
houses.head(2)
# Out:
#                                             pname                 society  \
# 0  3 Bedroom House for sale in Kolar Road, Bhopal  ultimate english villa
# 1    4 Bedroom House for sale in Lalghati, Bhopal           globus greens
#
#   property_type  price_outer  price_per_sqft      possesion  \
# 0         House         60.0            8534  Ready To Move
# 1         House        225.0           15000  Ready To Move
#
#                                          description  \
# 0             Na....................................
# 1  It's very spacious bunglow ..It's prime locati...
#
#                                                 Area  Total Floors Facing  \
# 0             Plot area 703\n(65.31 sq.m.)  \nsq.ft.           2.0   West
# 1  Plot area 1500\n(139.35 sq.m.)\nBuilt Up area:...           2.0   West
#
#        Property Age                                         furnishing  \
# 0  5 to 10 Year Old  ['2 Wardrobe', '1 Light', '1 Modular Kitchen',...
# ...

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.shape
# Out:
# (1580, 19)

# %%
df.sample(5)
# Out:
#                                                   pname             society  \
# 102                        4 BHK Flat in Misrod, Bhopal  globus coral woods
# 1364  2 Bedroom House for sale in Krishna Nagar, Bhopal       krishna nagar
# 352                        2 BHK Flat in Misrod, Bhopal       aryan heights
# 532               1 BHK Flat in Ayodhya Bypass , Bhopal       paras heights
# 1018    5 Bedroom House for sale in Basant Kunj, Bhopal         basant kunj
#
#      property_type  price_outer  price_per_sqft      possesion  \
# 102           Flat        93.00            4823  Ready To Move
# 1364         House         6.25            1388  Ready To Move
# 352           Flat        25.00            3571  Ready To Move
# 532           Flat        14.00            3111  Ready To Move
# 1018         House       275.00           12222  Ready To Move
#
#                                             description  \
# 102   Globus coral woods is one of the most popular ...
# ...

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.to_csv('BPL_merged_cleaned_l2.csv',index=False)
